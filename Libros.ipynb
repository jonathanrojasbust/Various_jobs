# %%
import pandas as pd

# %% [markdown]
# # Nueva sección

# %%
df = pd.DataFrame({"Nombre del Libro":["Java a Fondo" , "Deep Learning", "Arquitectura Limpia", "Big Data con Python"]})

# %%
df
# Out:
#       Nombre del Libro
# 0         Java a Fondo
# 1        Deep Learning
# 2  Arquitectura Limpia
# 3  Big Data con Python

# %%
df = pd.DataFrame({"Nombre del Libro":["Java a Fondo" , "Deep Learning", "Arquitectura Limpia", "Big Data con Python"] , "Autor":["Pablo Augusto Szn" , "Jordy Torres" , "Uncle Bob" , "Jose Manuel Ortega"] , "Numero de Paginas": [450, 350, 420, 408], "Precio":[120000,78000,230000,90000]})

# %%
df
# Out:
#       Nombre del Libro               Autor  Numero de Paginas  Precio
# 0         Java a Fondo   Pablo Augusto Szn                450  120000
# 1        Deep Learning        Jordy Torres                350   78000
# 2  Arquitectura Limpia           Uncle Bob                420  230000
# 3  Big Data con Python  Jose Manuel Ortega                408   90000

# %%
df[['Nombre del Libro','Precio']]
# Out:
#       Nombre del Libro  Precio
# 0         Java a Fondo  120000
# 1        Deep Learning   78000
# 2  Arquitectura Limpia  230000
# 3  Big Data con Python   90000

# %% [markdown]
# Usamos loc para encontrar el indice de la posicion que nos interesa mostrar.

# %%
df.loc[[1,2]]
# Out:
#       Nombre del Libro         Autor  Numero de Paginas  Precio
# 1        Deep Learning  Jordy Torres                350   78000
# 2  Arquitectura Limpia     Uncle Bob                420  230000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Nombre del Libro   4 non-null      object
#  1   Autor              4 non-null      object
#  2   Numero de Paginas  4 non-null      int64
#  3   Precio             4 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 256.0+ bytes

# %%
df2 = pd.read_csv('Compras.csv')

# %%
df2
# Out:
#         Cliente   cantidad      medio_pago
# 0    Juan Perez          1        Efectivo
# 1   Pepito Ruiz          2   Transferencia
# 2  Maria Castro          1        Efectivo
# 3         Cesde          5         Credito

# %%
df3 = pd.concat([df,df2], axis=1)

# %%
df3
# Out:
#       Nombre del Libro               Autor  Numero de Paginas  Precio  \
# 0         Java a Fondo   Pablo Augusto Szn                450  120000
# 1        Deep Learning        Jordy Torres                350   78000
# 2  Arquitectura Limpia           Uncle Bob                420  230000
# 3  Big Data con Python  Jose Manuel Ortega                408   90000
#
#         Cliente   cantidad      medio_pago
# 0    Juan Perez          1        Efectivo
# 1   Pepito Ruiz          2   Transferencia
# 2  Maria Castro          1        Efectivo
# 3         Cesde          5         Credito

# %%
df3.to_csv('ventas.csv')

# %%
df3.to_excel('ventas.xlsx')

# %% [markdown]
# # Practica Analitica

# %% [markdown]
# # Importando Pandas
