# %%
import pandas as pd

# %%
datos_vivienda = pd.read_csv('alquiler.csv', sep = ";")

# %%
datos_vivienda
# Out:
#                   Tipo    Distrito  Cuartos  Vacantes  Suites  Area   Valor  \
# 0           Habitación   San Borja        1         0       0    40  1700.0
# 1                 Casa  Lurigancho        2         0       1   100  7000.0
# 2      Local comercial         Ate        0         4       0   150  5200.0
# 3         Departamento  Pachacámac        1         0       0    15   800.0
# 4         Departamento         Ate        1         0       0    48   800.0
# ...                ...         ...      ...       ...     ...   ...     ...
# 32955       Habitación  Pachacámac        0         0       0    27   800.0
# 32956     Departamento       Lince        3         1       2    78  1800.0
# 32957     Departamento       Rímac        2         1       0    48  1400.0
# 32958     Departamento       Rímac        2         0       0    70  3000.0
# 32959  Local comercial  Pachacámac        0         0       0   250  6500.0
#
#        Mantenimiento  Impuesto
# ...

# %%
sel_departamentos = datos_vivienda["Tipo"] == "Departamentos"
cant_otra_vivi = datos_vivienda[~sel_departamentos].shape[0]
cant_otra_vivi
# Out:
# 32960

# %%
sel_casa_hab_cochera = (datos_vivienda["Tipo"] == "Casa" ) | (datos_vivienda["Tipo" == "Habitacion"]) | (datos_vivienda["Tipo"] == "Cochera")
cant_dpto_casa_hab_cochera = datos_vivienda[sel_casa_hab_cochera].shape[0]
cant_dpto_casa_hab_cochera
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
sel_area = (datos_vivienda ['Area'] >=60) & (datos_vivienda['Area'] <=100)
sel_area
cant_viv_area = datos_vivienda[sel_area].shape[0]
cant_viv_area
# Out:
# 10187

# %%
sel_hab_precio = (datos_vivienda['Cuartos'] >=4)&(datos_vivienda['Valor'] <= 2000)
cant_hab_precio = datos_vivienda[sel_hab_precio].shape[0]
cant_hab_precio
# Out:
# 62

# %%
print("Se encontraron los siguientes resultados")
print(f"El numero de departamentos es de: {cant_dpto}")
print(f"El Numero de viviendas restantes es de: {cant_otra_vivi}")
print(f"El Numero de viviendas tipo Casa, Habitacion y Cochera es de {cant_dpto_casa_hab_cochera}")
print(f"La cantidad de viviendas con un area entre 60 y 100 metros cuadrados es de {cant_dpto_casa_hab_cochera}")
print(f"La cantidad de viviendas con al menos 4 habitaciones y con un valor menor o igual a 2000  es: {cant_hab_precio}")
# Out:
# Se encontraron los siguientes resultados
# El numero de departamentos es de: 32960
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-6e7b1fe2ca86> in <cell line: 3>()
#       1 print("Se encontraron los siguientes resultados")
#       2 print(f"El numero de departamentos es de: {cant_dpto}")
# ----> 3 print(f"El Numero de viviendas restantes es de: {cant_otra_vivi}")
#       4 print(f"El Numero de viviendas tipo Casa, Habitacion y Cochera es de {cant_dpto_casa_hab_cochera}")
#       5 print(f"La cantidad de viviendas con un area entre 60 y 100 metros cuadrados es de {cant_dpto_casa_hab_cochera}")
#
# NameError: name 'cant_otra_vivi' is not defined

# %% [markdown]
# # Manejo de datos faltantes

# %%
datos_vivienda.isnull()
# Out:
#         Tipo  Distrito  Cuartos  Vacantes  Suites   Area  Valor  \
# 0      False     False    False     False   False  False  False
# 1      False     False    False     False   False  False  False
# 2      False     False    False     False   False  False  False
# 3      False     False    False     False   False  False  False
# 4      False     False    False     False   False  False  False
# ...      ...       ...      ...       ...     ...    ...    ...
# 32955  False     False    False     False   False  False  False
# 32956  False     False    False     False   False  False  False
# 32957  False     False    False     False   False  False  False
# 32958  False     False    False     False   False  False  False
# 32959  False     False    False     False   False  False  False
#
#        Mantenimiento  Impuesto
# 0              False     False
# 1               True      True
# 2              False     False
# 3              False     False
# 4              False      True
# ...

# %%
datos_vivienda[datos_vivienda['Valor'].isnull()]
# Out:
#                              Tipo     Distrito  Cuartos  Vacantes  Suites  \
# 76                   Departamento          Ate        2         1       1
# 2186                 Departamento  San Bartolo        2         0       0
# 2456                         Casa        Lince        3         4       3
# 2646                 Tienda/Salón          Ate        0         2       0
# 2941                 Departamento   Chorrillos        2         0       0
# 2973                 Departamento    San Borja        2         0       0
# 6598                 Tienda/Salón     La Punta        0         0       0
# 7302                         Casa        Lince        3         2       1
# 12683                Departamento  San Bartolo        2         0       1
# 13229                Departamento     La Punta        3         0       1
# 13525                Departamento     La Perla        3         1       1
# 13579             Local comercial   Chorrillos        0         3       0
# ...

# %%
from re import sub
vivienda_nan = datos_vivienda.shape[0]
datos_vivienda.dropna(subset= ['Valor'], inplace= True)
vivienda_nan_b = datos_vivienda.shape[0]
vivienda_nan - vivienda_nan_b
# Out:
# 17

# %%
datos_vivienda[datos_vivienda ['Valor'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Tipo, Distrito, Cuartos, Vacantes, Suites, Area, Valor, Mantenimiento, Impuesto]
# Index: []

# %% [markdown]
# # Cuando la desicion es conservar los datos, debemos sobre escribir con un valor, en este caso (0), para conservar la fila.

# %%
datos_vivienda[datos_vivienda['Mantenimiento'].isnull()].shape[0]
# Out:
# 4089

# %%
sel = (datos_vivienda['Tipo'] == 'Departamento')&(datos_vivienda["Mantenimiento"].isnull())

# %%
sel_A = datos_vivienda.shape[0]
datos_vivienda = datos_vivienda[~sel]
datos_vivienda
sel_B = datos_vivienda.shape[0]
sel_A - sel_B
# Out:
# <ipython-input-32-816e3be4f929>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   datos_vivienda = datos_vivienda[~sel]
# 0
